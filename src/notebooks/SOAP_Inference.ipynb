# %% [markdown]
# ### SOAP Mistral Inference

# %% [markdown]
# ### Installing and importing packages

# %%
# install unsloth package
# !pip install "unsloth[colab] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting unsloth[colab]@ git+https://github.com/unslothai/unsloth.git
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-zakd5cvo/unsloth_8d788986c74947eaa7f2fd32b8260a3d
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-zakd5cvo/unsloth_8d788986c74947eaa7f2fd32b8260a3d
#   Resolved https://github.com/unslothai/unsloth.git to commit 72aee4a3a128268c3d1e5cef249626897996645c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.43.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.25.2)
# Collecting xformers@ https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Using cached https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl (211.8 MB)
# Requirement already satisfied: tyro in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.8.3)
# Requirement already satisfied: transformers>=4.38.2 in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.40.1)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.19.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.43.0)
# Requirement already satisfied: accelerate>=0.26.1 in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.29.3)
# Requirement already satisfied: trl>=0.7.9 in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.8.6)
# Requirement already satisfied: peft>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.10.0)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.1->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (23.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.1->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.1->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.1->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.13.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.9.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.19.1)
# Requirement already satisfied: docstring-parser>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (13.7.1)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)

# %%
# !pip install --upgrade --quiet  "optimum[onnxruntime]" langchain  langchain-experimental langchain-openai

# %%
# !pip install gptrim
# Out:
# Requirement already satisfied: gptrim in /usr/local/lib/python3.10/dist-packages (0.1.6)
# Requirement already satisfied: nltk==3.8.1 in /usr/local/lib/python3.10/dist-packages (from gptrim) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->gptrim) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->gptrim) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->gptrim) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->gptrim) (4.66.2)

# %%
transcribed_text = """0000.0s 0000.9s Doctor:  what brought you in today?
0002.0s 0002.4s Patient: Sure.
0002.4s 0009.5s Patient: I'm just having a lot of chest pain and so I thought I should get it checked out.
0011.4s 0011.8s Doctor: Okay.
0012.9s 0019.7s Doctor: And before we start, could you remind me of your gender and age?
0020.6s 0020.8s Patient: Sure.
0020.9s 0021.4s Patient: I'm 39.
0021.5s 0023.6s Patient: I'm a male.
0024.6s 0026.5s Doctor: Okay.
0027.3s 0029.6s Doctor: And so when did this chest pain start?
0032.1s 0036.3s Patient:  It started last night, but it's becoming sharper.
0038.0s 0041.7s Doctor: Okay, and where is this pain located?
0043.2s 0045.5s Patient: It's located on the left side of my chest.
0046.9s 0054.7s Doctor: Okay, and so how long has it been going on for than if it started last night?
0056.1s 0060.2s Patient: So I guess it would be a couple hours now, maybe like
0061.1s 0061.3s Patient:  Eight.
0062.8s 0064.5s Doctor: Okay.
0065.4s 0070.4s Doctor: Has it been constant throughout that time or changing?
0072.1s 0075.4s Patient: I would say it's been pretty constant, yeah.
0076.5s 0076.9s Doctor: Okay.
0077.4s 0079.8s Doctor: And how would you describe the pain?
0081.4s 0085.1s Doctor: People will use words sometimes like sharp, burning, achy.
0086.5s 0087.8s Patient: I'd say it's pretty sharp, yeah.
0088.9s 0089.6s Doctor: Sharp, okay.
0090.8s 0097.8s Doctor:  Um, anything that you, uh, have done, tried, um, since last night that's made the pain better?
0097.9s 0101.9s Patient: Um, not laying down helps.
0103.6s 0104.1s Doctor: Okay.
0104.2s 0107.0s Doctor: So do you find laying down makes the pain worse?
0107.8s 0109.4s Patient: Yes, definitely.
0111.2s 0111.5s Doctor: Okay.
0112.5s 0116.4s Doctor: Um, do you find that the pain is radiating anywhere?
0116.4s 0116.4s Doctor: No.
0121.0s 0121.4s Doctor:  Okay.
0121.8s 0126.9s Doctor: And is there anything else that makes the pain worse besides laying down?
0127.8s 0128.8s Patient: Not that I've noticed.
0129.0s 0129.3s Patient: No.
0130.8s 0131.2s Doctor: Okay.
0131.3s 0135.0s Doctor: So not like taking a deep breath or anything like that?
0136.1s 0137.4s Patient: Maybe taking a deep breath.
0496.0s 0501.2s Doctor:  And do you use any other recreational drugs like cocaine, crystal meth?
0502.1s 0502.5s Doctor: No.
0502.6s 0503.2s Doctor: Opioids?
0504.0s 0504.2s Patient: No.
0504.9s 0506.1s Doctor: Okay.
0506.5s 0508.0s Doctor: Have you used IV drugs before?
0508.0s 0508.1s Doctor: No.
0510.0s 0511.4s Doctor: Okay.
0512.0s 0513.4s Doctor: And do you drink alcohol?
0514.5s 0514.8s Patient: I do.
0515.5s 0515.9s Doctor: Okay.
0516.4s 0520.1s Doctor: How much alcohol do you drink each week?
0521.3s 0523.0s Patient: About
0525.0s 0529.7s Patient:  I'd say I'd have one or two drinks a day, so about 10 drinks a week.
0531.1s 0532.5s Doctor: Okay.
0533.9s 0541.8s Doctor: And then briefly, could you tell me a little bit about your diet and exercise?
0542.9s 0543.2s Patient: Sure.
0543.3s 0544.5s Patient: I try to eat healthy for
0548.1s 0552.6s Patient:  dinner at least, but most of my lunches are, I eat out.
0553.0s 0557.5s Patient: And then in terms of exercise, I try to exercise every other day.
0557.5s 0560.5s Patient: I run for about half an hour.
0561.8s 0562.2s Doctor: Okay.
0562.6s 0568.1s Doctor: Oh, that's great that you've been working on the activity and the diet as well.
0570.0s 0573.5s Doctor: So has anything like this happened in your family before?
0573.5s 0573.5s Doctor: No.
0575.8s 0576.2s Doctor:  Okay.
0576.4s 0578.9s Doctor: Has anybody in the family had a heart attack before?
0581.1s 0581.8s Patient: Actually, yes.
0581.8s 0585.3s Patient: My father had a heart attack when he was 45.
0586.5s 0586.9s Doctor: Okay.
0587.5s 0591.8s Doctor: And anybody in the family have cholesterol problems?
0593.9s 0595.0s Patient: I think my father did.
0595.0s 0596.5s Doctor: I see.
0596.6s 0597.0s Doctor: Okay.
0597.5s 0600.0s Doctor: And how about anybody in the family have stroke
0601.8s 0602.4s Patient:  No strokes.
0603.4s 0603.7s Doctor: Okay.
0604.0s 0606.3s Doctor: And then, um, any cancers in the family?
0606.3s 0606.3s Doctor: No.
0607.3s 0607.5s Patient: No.
0609.3s 0609.7s Doctor: Okay.
0610.7s 0619.2s Doctor: Um, is, was there anything else that you wanted to, um, tell me about today that, that on, on history?
0619.2s 0622.4s Patient: Uh, no, I don't think so.
0622.4s 0625.5s Patient: I think you asked me everything."""

# %%
# creating pipeline

from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import torch

tokenizer = AutoTokenizer.from_pretrained("ProtectAI/deberta-v3-base-prompt-injection")
model = AutoModelForSequenceClassification.from_pretrained("ProtectAI/deberta-v3-base-prompt-injection")

classifier = pipeline(
  "text-classification",
  model=model,
  tokenizer=tokenizer,
  truncation=True,
  max_length=2048,
  device=torch.device("cuda" if torch.cuda.is_available() else "cpu"),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# formatting conversation

conversation = transcribed_text


lines = conversation.strip().split("\n")


combined_sentences = ""


for line in lines:

    parts = line.split(" ")


    if len(parts) >= 3:

        sentence = " ".join(parts[2:])

        combined_sentences += sentence.strip() + " "


print(combined_sentences)
# Out:
# Doctor:  what brought you in today? Patient: Sure. Patient: I'm just having a lot of chest pain and so I thought I should get it checked out. Doctor: Okay. Doctor: And before we start, could you remind me of your gender and age? Patient: Sure. Patient: I'm 39. Patient: I'm a male. Doctor: Okay. Doctor: And so when did this chest pain start? Patient:  It started last night, but it's becoming sharper. Doctor: Okay, and where is this pain located? Patient: It's located on the left side of my chest. Doctor: Okay, and so how long has it been going on for than if it started last night? Patient: So I guess it would be a couple hours now, maybe like Patient:  Eight. Doctor: Okay. Doctor: Has it been constant throughout that time or changing? Patient: I would say it's been pretty constant, yeah. Doctor: Okay. Doctor: And how would you describe the pain? Doctor: People will use words sometimes like sharp, burning, achy. Patient: I'd say it's pretty sharp, yeah. Doctor: Sharp, okay. Doctor:  Um, anything that you, uh, have done, tried, um, since last night that's made the pain better? Patient: Um, not laying down helps. Doctor: Okay. Doctor: So do you find laying down makes the pain worse? Patient: Yes, definitely. Doctor: Okay. Doctor: Um, do you find that the pain is radiating anywhere? Doctor: No. Doctor:  Okay. Doctor: And is there anything else that makes the pain worse besides laying down? Patient: Not that I've noticed. Patient: No. Doctor: Okay. Doctor: So not like taking a deep breath or anything like that? Patient: Maybe taking a deep breath. Patient: Yeah. Doctor: Okay. Doctor: And, um, when the pain started, could you, um, tell me, could you think of anything that you were doing at the time? Patient:  I mean, I was moving some furniture around, but I've done that before. Doctor: Okay, so you didn't feel like you hurt yourself when you were doing that? Patient: No. Doctor:  Okay, and in regards to how severe the pain is, on a scale of 1 to 10, 10 being the worst pain you've ever felt, how severe would you say the pain is? Patient: I'd say it's like a 7 or 8. Patient: It's pretty bad. Doctor: Okay, and with the pain, do you have any other associated symptoms? Patient:  I feel a little lightheaded and I'm having some trouble breathing. Doctor: Okay. Doctor: Um, um, have you, uh, had any, um, loss of consciousness? Patient: No. Doctor: Okay. Doctor: Um, have you been experiencing any, uh, like racing of the heart? Patient: Um, a little bit. Patient: Yeah. Doctor: Okay. Doctor:  And have you been sweaty at all? Patient: Just from having issues breathing. Doctor: Okay. Doctor: Have you been having issues breathing since the pain started? Patient: Yes. Doctor: Okay. Doctor: And recently, have you had any periods of time where you Doctor:  like have been immobilized or you haven't been, um, like able to move around a lot? Patient: No, no. Doctor: Okay. Doctor: Um, and, um, have you been feeling sick at all? Doctor: Any infectious symptoms? Patient: No. Doctor: Okay. Doctor: Have you had any nausea or vomiting? Patient: No. Doctor: Any fevers or chills? Patient: No. Doctor:  Okay. Doctor: How about any abdominal pain? Patient: No. Doctor: Any urinary problems? Patient: No. Doctor: Or bowel problems? Doctor: Okay. Doctor: Have you had a cough? Patient: No. Doctor: Okay. Doctor: You haven't brought up any blood with a cough? Doctor: No. Doctor: Okay. Doctor: Have you had a wheeze with your difficulty breathing? Patient:  No, not that I've heard. Doctor: Okay, any changes to the breath sounds at all? Doctor: Any noisy breathing? Patient: No. Patient: Well, I guess when I'm really having trouble breathing, yeah. Doctor: Okay. Doctor: Has anything like this ever happened to you before? Doctor: No. Patient: No. Patient: Okay. Doctor:  And have you had any night sweats? Patient: No. Doctor: All right. Doctor: And then how about any rashes or skin changes? Patient: No rashes, but I guess like my neck seems to be a little swollen. Doctor: Okay ...

# %%
from gptrim import trim

injection_result = classifier(transcribed_text)

if injection_result[0]['label'] == 'SAFE':
  compressed_text = trim(combined_sentences)
  print(compressed_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Doctor:broughttoday?Patient:Sure.Patient:Imlotchestpainthoughtgetchecked.Doctor:Okay.Doctor:start,couldremindgenderage?Patient:Sure.Patient:Im39.Patient:Immale.Doctor:Okay.Doctor:chestpainstart?Patient:startedlastnight,becomingsharper.Doctor:Okay,painlocated?Patient:locatedleftsidechest.Doctor:Okay,longgoingstartedlastnight?Patient:guesswouldcouplehours,maybelikePatient:Eight.Doctor:Okay.Doctor:constantthroughouttimechanging?Patient:wouldsayprettyconstant,yeah.Doctor:Okay.Doctor:woulddescribepain?Doctor:Peopleusewordssometimeslikesharp,burning,achy.Patient:Idsayprettysharp,yeah.Doctor:Sharp,okay.Doctor:Um,anything,uh,done,tried,um,sincelastnightthatsmadepainbetter?Patient:Um,notlayinghelps.Doctor:Okay.Doctor:findlayingmakespainworse?Patient:Yes,definitely.Doctor:Okay.Doctor:Um,findpainradiatinganywhere?Doctor:No.Doctor:Okay.Doctor:anythingelsemakespainworsebesideslaying?Patient:NotIvenoticed.Patient:No.Doctor:Okay.Doctor:notliketakingdeepbreathanythinglike?Patient:Maybetakingdeepbreath.Patient:Yeah.Doctor:Okay.Doctor:,um,painstarted,could,um,tell,couldthinkanythingtime?Patient:mean,movingfurniturearound,Ivedone.Doctor:Okay,didntfeellikehurt?Patient:No.Doctor:Okay,regardsseverepain,scale110,10worstpainyouveeverfelt,severewouldsaypain?Patient:Idsaylike78.Patient:prettybad.Doctor:Okay,pain,associatedsymptoms?Patient:feellittlelightheadedImtroublebreathing.Doctor:Okay.Doctor:Um,um,,uh,,um,lossconsciousness?Patient:No.Doctor:Okay.Doctor:Um,experiencing,uh,likeracingheart?Patient:Um,littlebit.Patient:Yeah.Doctor:Okay.Doctor:sweaty?Patient:issuesbreathing.Doctor:Okay.Doctor:issuesbreathingsincepainstarted?Patient:Yes.Doctor:Okay.Doctor:recently,periodstimeDoctor:likeimmobilizedhavent,um,likeablemovearoundlot?Patient:No,no.Doctor:Okay.Doctor:Um,,um,feelingsick?Doctor:infectioussymptoms?Patient:No.Doctor:Okay.Doctor:nauseavomiting?Patient:No.Doctor:feverschills?Patient:No.Doctor:Okay.Doctor:abdominalpain?Patient:No.Doctor:urinaryproblems?Patient:No.Doctor:bowelproblems?Doctor:Okay.Doctor:cough?Patient:No.Doctor:Okay.Doctor:haventbroughtbloodcough?Doctor:No.Doctor:Okay.Doctor:wheezedifficultybreathing?Patient:No,notIveheard.Doctor:Okay,changesbreathsounds?Doctor:noisybreathing?Patient:No.Patient:Well,guessImreallytroublebreathing,yeah.Doctor:Okay.Doctor:anythinglikeeverhappened?Doctor:No.Patient:No.Patient:Okay.Doctor:nightsweats?Patient:No.Doctor:right.Doctor:rashesskinchanges?Patient:Norashes,guesslikeneckseemslittleswollen.Doctor:Okay.Doctor:neckpain?Patient:No.Doctor:Okay.Doctor:,um,likeaccidents,like,likecaraccidentanythingreallyjerkedneck?Patient:No.Doctor:Okay.Doctor:Um,,traumachest,back?Patient:No.Doctor:Okay.Doctor:Um,regardspastmedicalhistory,um,,uh,priormedicalconditions?Patient:No.Doctor:Okay.Doctor:Um,,uh,recenthospitalizations?Patient:No.Doctor:Okay.Doctor:,uh,priorsurgeries?Patient:No.Doctor:Okay.Doctor:takemedicationsregularly?Doctor:prescribedcounter?Patient:No.Doctor:right.Doctor:allergiesmedications?Patient:None.Doctor:right.Doctor:immunizationsdate?Patient:Theyredate.Doctor:Excellent.Doctor:right.Doctor:couldtelllittlebitlivingsituationcurrently?Patient:Sure.Patient:liveapartment.Patient:Yep,thats.Patient:Okay.Doctor:supportfinancially?Patient:Imaccountant.Doctor:Okay.Doctor:Soundslikeprettystressfuljob.Doctor:smokecigarettes?Patient:.Doctor:Okay.Doctor:muchsmoke?Patient:smokepackday.Doctor:Okay.Doctor:longsmoking?Patient:past1015years.Doctor:Okay.Doctor:smokecannabis?Patient:Sometimes.Doctor:muchmarijuanawouldsmokeperweek?Patient:Perweek?Patient:Maybefivemilligrams,notmuch.Doctor:Okay.Doctor:userecreationaldrugslikecocaine,crystalmeth?Doctor:No.Doctor:Opioids?Patient:No.Doctor:Okay.Doctor:usedIVdrugs?Doctor:No.Doctor:Okay.Doctor:drinkalcohol?Patient:.Doctor:Okay.Doctor:muchalcoholdrinkweek?Patient:Patient:IdsayIdonetwodrinksday,10drinksweek.Doctor:Okay.Doctor:briefly,couldtelllittlebitdietexercise?Patient:Sure.Patient:tryeathealthyPatient:dinnerleast,lunches,eat.Patient:termsexercise,tryexerciseeveryday.Patient:runh ...

# %% [markdown]
# ### Model Inference

# %%
import torch
from unsloth import FastLanguageModel
from transformers import TextStreamer
import time

total =0
max_seq_length = 820
dtype =None
load_in_4bit = True

soap_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""
model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "m-masood/soap-mistral",
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )


model.to('cuda').half()
inputs = tokenizer(
[
    soap_prompt.format(
        "Below is an dialogue that shows conversation between doctor and patient, convert it into clinical soap format. Also extract patient gender and age from dialogue and include in the response", # instruction
        compressed_text,
        "",
    )
]*1, return_tensors = "pt").to("cuda")
start_time = time.time()
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 820)
end_time = time.time()
total = end_time - start_time
print(total)
# Out:
# Unused kwargs: ['quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# ==((====))==  Unsloth: Fast Mistral patching release 2024.4
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.1.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.22.post7. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Below is an dialogue that shows conversation between doctor and patient, convert it into clinical soap format. Also extract patient gender and age from dialogue and include in the response
#
# ### Input:
# Doctor:broughttoday?Patient:Sure.Patient:Imlotchestpainthoughtgetchecked.Doctor:Okay.Doctor:start,couldremindgenderage?Patient:Sure.Patient:Im39.Patient:Immale.Doctor:Okay.Doctor:chestpainstart?Patient:startedlastnight,becomingsharper.Doctor:Okay,painlocated?Patient:locatedleftsidechest.Doctor:Okay,longgoingstartedlastnight?Patient:guesswouldcouplehours,maybelikePatient:Eight.Doctor:Okay.Doctor:constantthroughouttimechanging?Patient:wouldsayprettyconstant,yeah.Doctor:Okay.Doctor:woulddescribepain?Doctor:Peopleusewordssometimeslikesharp,burning,achy.Patient:Idsayprettysharp,yeah.Doctor:Sharp,okay.Doctor:Um,anything,uh,done,tried,um,sincelastnightthatsmadepainbetter?Patient:Um,notlayinghelps.Doctor:Okay.Doctor:findlayingmakespainworse?Patient:Yes,definitely.Doctor:Okay.Doctor:Um,findpainradiatinganywhere?Doctor:No.Doctor:Okay.Doctor:anythingelsemakespainworsebesideslaying?Patient:NotIvenoticed.Patient:No.Doctor:Okay.Doctor:notliketakingdeepbreathanythinglike?Patient:Maybetakingdeepbreath.Patient:Yeah.Doctor:Okay.Doctor:,um,painstarted,could,um,tell,couldthinkanythingtime?Patient:mean,movingfurniturearound,Ivedone.Doctor:Okay,didntfeellikehurt?Patient:No.Doctor:Okay,regardsseverepain,scale110,10worstpainyouveeverfelt,severewouldsaypain?Patient:Idsaylike78.Patient:prettybad.Doctor:Okay,pain,associatedsymptoms?Patient:feellittlelightheadedImtroublebreathing.Doctor:Okay.Doctor:Um,um,,uh,,um,lossconsciousness?Patient:No.Doctor:Okay.Doctor:Um,experiencing,uh,likeracingheart?Patient:Um,littlebit.Patient:Yeah.Doctor:Okay.Doctor:sweaty?Patient:issuesbreathing.Doctor:Okay.Doctor:issuesbreathingsincepainstarted?Patient:Yes.Doctor:Okay.Doctor:recently,periodstimeDoctor:likeimmobilizedhavent,um,likeablemovearoundlot?Patient:No,no.Doctor:Okay.Doctor:Um,,um,feelingsick?Doctor:infectioussymptoms?Patient:No.Doctor:Okay.Doctor:nauseavomiting?Patient:No.Doctor:feverschills?Patient:No.Doctor:Okay.Doctor:abdominalpain?Patient:No.Doctor:urinaryproblems?Patient:No.Doctor:bowelproblems?Doctor:Okay.Doctor:cough?Patient:No.Doctor:Okay.Doctor:haventbroughtbloodcough?Doctor:No.Doctor:Okay.Doctor:wheezedifficultybreathing?Patient:No,notIveheard.Doctor:Okay,changesbreathsounds?Doctor:noisybreathing?Patient:No.Patient:Well,guessImreallytroublebreathing,yeah.Doctor:Okay.Doctor:anythinglikeeverhappened?Doctor:No.Patient:No.Patient:Okay.Doctor:nightsweats?Patient:No.Doctor:right.Doctor:rashesskinchanges?Patient:Norashes,guesslikeneckseemslittleswollen.Doctor:Okay.Doctor:neckpain?Patient:No.Doctor:Okay.Doctor:,um,likeaccidents,like,likecaraccidentanythingreallyjerkedneck?Patient:No.Doctor:Okay.Doctor:Um,,traumachest,back?Patient:No.Doctor:Okay.Doctor:Um,regardspastmedicalhistory,um,,uh,priormedicalconditions?Patient:No.Doctor:Okay.Doctor:Um,,uh,recenthospitalizations?Patient:No.Doctor:Okay.Doctor:,uh,priorsurgeries?Patient:No.Doctor:Okay.Doctor:takemedicationsregularly?Doctor:prescribedcounter?Patient:No.Doctor:right.Doctor:allergiesmedications?Patient:None.Doctor:right.Doctor:immunizationsdate?Patient:Theyredate.Doctor:Excellent.Doctor:right.Doctor:couldtelllittlebitlivingsituationcurrently?Patient:Sure.Patient:liveapartment.Patient:Yep,thats.Patient:Okay.Doctor:supportfinancially?Patient:Imaccountant.Doctor:Okay.Doctor:Soundslikeprettystressfuljob.Doctor:smokecigarettes?Patient:.Doctor:Okay.Doctor:muchsmoke?Patient:smokepackday.Doctor:Okay.Doctor:longsmoking?Patient:past1015years.Doctor:Okay.Doctor:smokecannabis?Patient:Sometimes.Doctor:muchmarijuanawouldsmokeperweek?Patient:Perweek?Patient:Maybefivemilligrams,notmuch.Doctor:Okay.Doctor:userecreationaldrugslikecocaine,crystalmeth?Doctor:No.Doctor:Opioids?Patient:No.Doctor:Okay.Doctor:usedIVdrugs?Doctor:No.Doctor:Okay.Doctor:drinkalcohol?Patient:.Doctor:Okay.Doctor:muchalcoholdrinkweek?Patient:Patient:IdsayIdonetwodrinksday,10drinksweek.Doctor:Okay.Doctor:briefly,couldtelllittlebitdietexercise?Patient:Sure.Patient:tryeathealthyPatient:dinnerleast,lunches,eat.Patient:termsexercise,tryexerciseeveryday.Patient:runh ...
#
# ### Response:
# Subjective:
#
# Chief Complaint: Chest pain.
#
# Onset: Started last night and has been getting sharper.
#
# Location: Left side of the chest.
#
# Duration: Started last night and has been getting sharper.
#
# Character: Sharp.
#
# Radiation: No radiation.
#
# Associated symptoms: Lightheadedness, trouble breathing, and feeling like moving furniture around caused the pain.
#
# Severity: 7-8 out of 10, the worst pain the patient has ever felt.
#
# Pain exacerbating factors: Laying down and taking deep breaths.
#
# Pain relieving factors: Lying down.
#
# Fever: No fever.
#
# Nausea or vomiting: No nausea or vomiting.
#
# Chills: No chills.
#
# Abdominal pain: No abdominal pain.
#
# Urinary problems: No urinary problems.
#
# Bowel problems: No bowel problems.
#
# Cough: No cough.
#
# Blood in cough: No blood in cough.
#
# Wheezing or difficulty breathing: No wheezing or difficulty breathing.
#
# Changes in breathing sounds: No changes in breathing sounds.
#
# Noisy breathing: No noisy breathing.
#
# Neck pain: No neck pain.
#
# Neck swelling: Neck seems a little swollen.
#
# Accidents or trauma: No accidents or trauma.
#
# Past medical conditions: No past medical conditions.
#
# Hospitalizations: No hospitalizations.
#
# Surgeries: No surgeries.
#
# Medications: No medications.
#
# Allergies: No allergies.
#
# Immunizations: Up to date with immunizations.
#
# Living situation: Lives in an apartment.
#
# Financial support: Works as an accountant, providing financial support.
#
# Smoking: Smokes cigarettes, smokes a pack a day, and has been smoking for 10-15 years.
#
# Cannabis use: Uses cannabis sometimes.
#
# Recreational drug use: Uses recreational drugs like marijuana.
#
# Opioid use: No opioid use.
#
# IV drug use: No IV drug use.
#
# Alcohol consumption: Drinks alcohol, consumes 1-2 drinks per day, and consumes 10 drinks per week.
#
# Exercise: Tries to exercise every day, runs for half an hour.
#
# Family history: Father had a heart attack at 45 and may have had high cholesterol.
#
# Objective:
#
# Vital signs: Blood pressure 120/80 mmHg, heart rate 80 bpm, respiratory rate 16 breaths/min, temperature 37.0°C.
#
# Physical examination: No abnormalities noted.
#
# Laboratory tests:
#
# Complete blood count: Normal.
#
# Chemistry panel: Normal.
#
# Electrolytes: Normal.
#
# Liver function tests: Normal.
#
# Renal function tests: Normal.
#
# Cardiac enzymes: Normal.
#
# D-dimer: Normal.
#
# Chest X-ray: No abnormalities noted.
#
# Electrocardiogram: No abnormalities noted.
#
# Assessment:
#
# Diagnosis: Chest pain, likely due to musculoskeletal causes.
#
# Plan:
#
# Reassurance and education on the likely cause of the chest pain.
#
# Referral to a physiotherapist for further evaluation and treatment.
#
# Follow-up in 1-2 weeks to assess the response to treatment.
#
# ###
# 66.27933979034424
